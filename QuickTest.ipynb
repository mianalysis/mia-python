# %%
# Main setup
import imagej
ij = imagej.init(['io.github.mianalysis:mia-plugin:2.0.0-SNAPSHOT'])

from jpype import JClass
from scyjava import jimport
from src.wrappers.obj import ObjWrapper
from src.wrappers.obj import PythonObjFactory
from src.wrappers.coordinateset import PythonCoordinateSetFactory
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Main setup
#       2 import imagej
# ----> 3 ij = imagej.init(['io.github.mianalysis:mia-plugin:2.0.0-SNAPSHOT'])
#       5 from jpype import JClass
#       6 from scyjava import jimport
#
# File ~/Documents/Programming/Python/mia-python/.pixi/envs/default/lib/python3.13/site-packages/imagej/__init__.py:1252, in init(ij_dir_or_version_or_endpoint, mode, add_legacy, headless)
#    1225         raise EnvironmentError(
#    1226             dedent("""\
#    1227             Cannot enable interactive mode in this environment.
#    (...)   1248         """)
#    1249         )
#    1251 if not sj.jvm_started():
# -> 1252     success = _create_jvm(ij_dir_or_version_or_endpoint, mode, add_legacy)
#    1253     if not success:
#    1254         raise RuntimeError("Failed to create a JVM with the requested environment.")
#
# File ~/Documents/Programming/Python/mia-python/.pixi/envs/default/lib/python3.13/site-packages/imagej/__init__.py:1393, in _create_jvm(ij_dir_or_version_or_endpoint, mode, add_legacy)
#    1390     _logger.debug(f"Adding option: {option}")
#    1391     sj.config.add_option(option)
# -> 1393 needs_unlock = _prepare_to_unlock_modules()
#    1395 # We want ImageJ2's endpoints to be first, so these will be restored later
#    1396 original_endpoints = sj.config.endpoints.copy()
#
# File ~/Documents/Programming/Python/mia-python/.pixi/envs/default/lib/python3.13/site-packages/imagej/__init__.py:1647, in _prepare_to_unlock_modules()
#    1646 def _prepare_to_unlock_modules() -> bool:
# -> 1647     major_version = _guess_java_version()
#    1649     if major_version is not None and major_version >= 9:
#    1650         # Allow illegal reflection access. Necessary for Java 17+.
#    1651         option = "--add-opens=java.base/java.lang=ALL-UNNAMED"
#
# File ~/Documents/Programming/Python/mia-python/.pixi/envs/default/lib/python3.13/site-packages/imagej/__init__.py:1577, in _guess_java_version()
#    1571 # In scyjava 1.12.0+, if a JDK fetch is planned, the jvm_version()
#    1572 # result will be invalid because that function is reporting on an
#    1573 # already-installed JVM available on the system. So let's be more
#    1574 # nuanced in how we predict the future here.
#    1575 fetch_plan = sj.config.get_fetch_java()
#    1576 will_fetch = fetch_plan == "always" or (
# -> 1577     fetch_plan == "auto" and version_digits is None
#    1578 )
#    1579 if will_fetch:
#    1580     version_to_fetch = sj.config.get_java_version()
#
# UnboundLocalError: cannot access local variable 'version_digits' where it is not associated with a value

# %%
obj_factory = PythonObjFactory()
coordinate_set_factory = PythonCoordinateSetFactory()
obj = obj_factory.createObj(None, coordinate_set_factory, 1, spat_cal=None)
print(obj.getFactory())

coordinate_set = obj.getCoordinateSet()
print(coordinate_set.size())
coordinate_set.add(2,1,3)
print(coordinate_set.size())
print(obj.getCoordinateSetFactory())
