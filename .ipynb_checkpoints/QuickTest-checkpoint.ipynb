# %%
# Main setup
import imagej
ij = imagej.init(['io.github.mianalysis:mia-plugin:2.0.0-SNAPSHOT'])

from jpype import JClass
from scyjava import jimport
from src.wrappers.obj import ObjWrapper
from src.wrappers.obj import PythonObjFactory
from src.wrappers.coordinateset import PythonCoordinateSetFactory

ObjCollection = jimport('io.github.mianalysis.mia.object.Objs')

obj_factory = PythonObjFactory()
coordinate_set_factory = PythonCoordinateSetFactory()
obj = obj_factory.createObj(None, coordinate_set_factory, 1, spat_cal=None)

coordinate_set = obj.getCoordinateSet()
coordinate_set.addCoord(2,1,3)
# Out:
# ScriptEngineManager providers.next(): javax.script.ScriptEngineFactory: Provider org.scijava.plugins.scripting.scala.ScalaScriptLanguage could not be instantiated
# ScriptEngineManager providers.next(): javax.script.ScriptEngineFactory: Provider org.scijava.plugins.scripting.scala.ScalaScriptLanguage could not be instantiated
# ScriptEngineManager providers.next(): javax.script.ScriptEngineFactory: Provider org.scijava.plugins.scripting.scala.ScalaScriptLanguage could not be instantiated
# ScriptEngineManager providers.next(): javax.script.ScriptEngineFactory: Provider org.scijava.plugins.scripting.scala.ScalaScriptLanguage could not be instantiated
# [ERROR] Cannot create plugin: org.scijava.plugins.scripting.scala.ScalaScriptLanguage
# [INFO] Overriding MIA; identifier: command:io.github.mianalysis.mia.MIA_; jar: file:/Users/sc13967/.jgo/io.github.mianalysis/mia-plugin/2.0.0-SNAPSHOT/d2fe3ba7f0550a523403e0d047b1788b5d374c2a09c72a0b89f635395f421067/mia-plugin-2.0.0-SNAPSHOT.jar
# [INFO] Overriding MIA (headless); identifier: command:io.github.mianalysis.mia.MIAHeadless; jar: file:/Users/sc13967/.jgo/io.github.mianalysis/mia-plugin/2.0.0-SNAPSHOT/d2fe3ba7f0550a523403e0d047b1788b5d374c2a09c72a0b89f635395f421067/mia-core-2.0.0-SNAPSHOT.jar
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      13 obj_factory = PythonObjFactory()
#      14 coordinate_set_factory = PythonCoordinateSetFactory()
# ---> 15 obj = obj_factory.createObj(None, coordinate_set_factory, 1, spat_cal=None)
#      17 coordinate_set = obj.getCoordinateSet()
#      18 coordinate_set.addCoord(2,1,3)
#
# File ~/Documents/Programming/Python/mia-python/src/wrappers/obj.py:278, in PythonObjFactory.createObj(self, obj_collection, factory, ID, spat_cal)
#     276 @JOverride
#     277 def createObj(self, obj_collection, factory, ID, spat_cal=None):
# --> 278     return ObjWrapper(obj_collection, factory, ID, spat_cal)
#
# File ~/Documents/Programming/Python/mia-python/.pixi/envs/default/lib/python3.12/site-packages/jpype/_jproxy.py:90, in _createJProxy.<locals>.new(tp, *args, **kwargs)
#      88 def new(tp, *args, **kwargs):
#      89     self = _jpype._JProxy.__new__(tp, None, actualIntf)
# ---> 90     tp.__init__(self, *args, **kwargs)
#      91     return self
#
# File ~/Documents/Programming/Python/mia-python/src/wrappers/obj.py:21, in ObjWrapper.__init__(self, obj_collection, coordinate_set_factory, ID, spat_cal)
#      19 def __init__(self, obj_collection, coordinate_set_factory, ID, spat_cal=None):
#      20     if spat_cal is None:
# ---> 21         spat_cal = obj_collection.getSpatialCalibration()
#      23     VolumeWrapper.__init__(self, coordinate_set_factory, spat_cal=spat_cal)
#      24     self._ID = ID
#
# AttributeError: 'NoneType' object has no attribute 'getSpatialCalibration'

# %%
obj.addCoord(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 obj.addCoord(1,2,3)
#
# File ~/Documents/Programming/Python/mia-python/src/wrappers/obj.py:263, in ObjWrapper.addCoord(self, x, y, z)
#     262 def addCoord(self, x, y, z):
# --> 263     VolumeAdaptor.addCoord(self, x, y, z)
#
# File ~/Documents/Programming/Python/mia-python/src/wrappers/volume.py:139, in VolumeWrapper.getWidth(self)
#     138 def getWidth(self):
# --> 139     return VolumeAdaptor.getWidth(self)
#
# File ~/Documents/Programming/Python/mia-python/src/wrappers/obj.py:135, in ObjWrapper.toString(self)
#     133 @JOverride
#     134 def toString(self):
# --> 135     return "Object \"" + self.getName() + "\", ID = " + self.getID() + ", frame = " + self.getT()
#
# File ~/Documents/Programming/Python/mia-python/src/wrappers/obj.py:35, in ObjWrapper.getName(self)
#      33 @JOverride
#      34 def getName(self):
# ---> 35     return self._obj_collection.getName()
#
# AttributeError: 'NoneType' object has no attribute 'getName'
